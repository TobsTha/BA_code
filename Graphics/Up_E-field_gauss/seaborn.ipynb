# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def gaussian(x, A, mu, sig): #A: Flaeche der Gaussfunktion
    return A/(sqrt(2*pi)*sig)*exp(-(x-mu)**2/2/sig**2)

# %%
filename = 'data\\initialFF_0.782.txt'
data = np.loadtxt(filename, delimiter=',', skiprows=0, dtype=str)
substraction_variable_amount = 4  #(without the features and the first three values are not correct)
data_amount = len(data) - substraction_variable_amount
print(data[0])
data = np.array(data.transpose())
print(data_amount)
print(data[0])
# Out:
# ['x(m)' ' Y']
# 2462
# ['x(m)' '-9.00747e-06' '-8.97747e-06' ... '6.484e-05' '6.487e-05'
#  '6.49e-05']

# %%
# print(data[0][1:])
print(data[0, 1:5])
# Out:
# ['-9.00747e-06' '-8.97747e-06' '-8.94748e-06' '-8.91748e-06']

# %%
x = 5
plt.plot(data[0, 1:x], data[1, 1:x])
plt.xlabel('x-position')
plt.ylabel('E-field')
# Out:
# Text(0, 0.5, 'E-field')
