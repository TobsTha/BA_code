# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data_path = 'data\\up_T.txt'
data_current = pd.read_csv(data_path, sep=",", header=None)
# print(data_current)
transmission = pd.to_numeric(data_current.iloc[1:,1].T)
period = np.linspace(880, 900, 11)
period_square = period**2
print(transmission)
print(period_square)
# Out:
# 1     0.427751
# 2     0.438547
# 3     0.446720
# 4     0.452447
# 5     0.456227
# 6     0.457739
# 7     0.456713
# 8     0.454224
# 9     0.450746
# 10    0.440921
# 11    0.431512
# Name: 1, dtype: float64
# [774400. 777924. 781456. 784996. 788544. 792100. 795664. 799236. 802816.
#  806404. 810000.]

# %%
ticklabelsize = 14
labelsize = 17

fig, ax = plt.subplots(1, 1, figsize=(3, 2)) 
ax.plot(period, transmission, linewidth = 2)
ax.set_xlabel('period', fontsize = labelsize)
ax.set_xticks(period[::2])
ax.set_xticklabels(period[::2].astype(int))
ax.set_ylabel('transmission T', fontsize = labelsize)

ax.tick_params(axis = 'both',  labelsize = ticklabelsize)
ax.grid(linestyle = ':')
# plt.tight_layout()
plt.show()
fig.savefig('up_T.png', dpi=300, bbox_inches='tight')

# %%
ticklabelsize = 14
labelsize = 17

fig, ax = plt.subplots(1, 1, figsize=(6, 4)) 
ax.plot(period, transmission, linewidth = 2)
ax.set_xlabel('period', fontsize = labelsize)
# ax.set_xticks(period)
# ax.set_xticklabels(period)
ax.set_ylabel('transmission T', fontsize = labelsize)

ax.tick_params(axis = 'both',  labelsize = ticklabelsize)
ax.grid(linestyle = ':')
plt.show()

fig.savefig('up_T.png')
